# %%
import pandas as pd
import sqlite3

DB = "predictions.sqlite"
PRICE_DB = "coin_prices.db"
POSITIONS_TABLE = "positions"
PREDICTIONS_TABLE = "coin_predictions"

# Load positions
conn = sqlite3.connect(DB)
pos_df = pd.read_sql_query(f"SELECT * FROM {POSITIONS_TABLE}", conn)
pred_df = pd.read_sql_query(f"SELECT * FROM {PREDICTIONS_TABLE}", conn)

# %%
pred_df
# Out:
#         id coin_id prediction_date target_date  predicted_price actual_price  \
# 0        1     sui      2025-07-13  2025-07-13         3.464831         None
# 1        2     sui      2025-07-13  2025-07-14         3.468533         None
# 2        3     sui      2025-07-13  2025-07-15         3.467800         None
# 3        4     sui      2025-07-13  2025-07-16         3.467945         None
# 4        5     sui      2025-07-13  2025-07-17         3.467916         None
# ...    ...     ...             ...         ...              ...          ...
# 1240  1241     one      2026-03-07  2026-03-07         0.000610         None
# 1241  1242     one      2026-03-07  2026-03-08         0.000607         None
# 1242  1243     one      2026-03-07  2026-03-09         0.000607         None
# 1243  1244     one      2026-03-07  2026-03-10         0.000607         None
# 1244  1245     one      2026-03-07  2026-03-11         0.000607         None
#
#             model_name           created_at
# ...

# %%
DB_PATH = "coin_prices.db"
conn = sqlite3.connect("coin_prices.db")
prices_df = pd.read_sql_query(f"SELECT * FROM coin_prices", conn)
prices_df
# Out:
#              date     price coin_id coin_name       ma7      ma14      ma30  \
# 0      2024-07-14  0.757892     sui       Sui       NaN       NaN       NaN
# 1      2024-07-15  0.806352     sui       Sui       NaN       NaN       NaN
# 2      2024-07-16  0.848276     sui       Sui       NaN       NaN       NaN
# 3      2024-07-17  0.868839     sui       Sui       NaN       NaN       NaN
# 4      2024-07-18  0.841489     sui       Sui       NaN       NaN       NaN
# ...           ...       ...     ...       ...       ...       ...       ...
# 32150  2026-03-04  0.369725   kaito     KAITO  0.338248  0.319249  0.323009
# 32151  2026-03-05  0.358293   kaito     KAITO  0.342461  0.323193  0.322809
# 32152  2026-03-06  0.355785   kaito     KAITO  0.346816  0.327368  0.322463
# 32153  2026-03-07  0.357537   kaito     KAITO  0.349038  0.330742  0.322488
# 32154  2026-03-07  0.357059   kaito     KAITO  0.351182  0.334708  0.324501
#
# ...

# %%
import pyodbc
from azure.identity import DefaultAzureCredential

# Acquire token
credential = DefaultAzureCredential()
access_token = credential.get_token("https://database.windows.net/.default").token

# Connection string (no Authentication keyword)
conn_str = (
    "Driver={ODBC Driver 18 for SQL Server};"
    "Server=tcp:cryptopp.database.windows.net,1433;"
    "Database=cryptopp;"
    "Encrypt=yes;TrustServerCertificate=no;Connection Timeout=30;"
)

# Pass token correctly
conn = pyodbc.connect(conn_str, attrs_before={1256: access_token})

cursor = conn.cursor()
cursor.execute("SELECT @@VERSION")
print(cursor.fetchone())
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[1], line 17
#       9 conn_str = (
#      10     "Driver={ODBC Driver 18 for SQL Server};"
#      11     "Server=tcp:cryptopp.database.windows.net,1433;"
#      12     "Database=cryptopp;"
#      13     "Encrypt=yes;TrustServerCertificate=no;Connection Timeout=30;"
#      14 )
#      16 # Pass token correctly
# ---> 17 conn = pyodbc.connect(conn_str, attrs_before={1256: access_token})
#      19 cursor = conn.cursor()
#      20 cursor.execute("SELECT @@VERSION")
#
# Error: ('HY000', 'The driver did not supply an error!')

# %%
import pyodbc

# Connection string using SQL authentication
conn_str = (
    "Driver={ODBC Driver 18 for SQL Server};"
    "Server=tcp:cryptopp.database.windows.net,1433;"
    "Database=cryptopp;"
    "Uid=cryptoppadmin;"          # Replace with your SQL login
    "Pwd=HappyMonu@0311;"          # Replace with your SQL password
    "Encrypt=yes;"
    "TrustServerCertificate=no;"
    "Connection Timeout=30;"
)

# Connect
conn = pyodbc.connect(conn_str)
cursor = conn.cursor()

# Test query
cursor.execute("SELECT @@VERSION")
print(cursor.fetchone())
# Out:
# ('Microsoft SQL Azure (RTM) - 12.0.2000.8 \n\tFeb  7 2026 14:31:25 \n\tCopyright (C) 2025 Microsoft Corporation\n',)

# %%
import pyodbc

server = 'crypoapp.database.windows.net'
database = 'crypopp'
client_id = 'fe2441fc-6dc0-4b47-93fb-8c501fce003c'
client_secret = '62l8Q~lRShfOFM4O~vQCF4y9U1lJtuwwB95JAbQ7'

connection_string = f'DRIVER={{ODBC Driver 18 for SQL Server}};SERVER={server};DATABASE={database};UID={client_id};PWD={client_secret};Authentication=ActiveDirectoryServicePrincipal'

connection = pyodbc.connect(connection_string)
cursor = connection.cursor()

# Example query
cursor.execute("SELECT @@version;")
row = cursor.fetchone()
while row:
    print(row[0])
    row = cursor.fetchone()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[5], line 10
#       6 client_secret = '62l8Q~lRShfOFM4O~vQCF4y9U1lJtuwwB95JAbQ7'
#       8 connection_string = f'DRIVER={{ODBC Driver 18 for SQL Server}};SERVER={server};DATABASE={database};UID={client_id};PWD={client_secret};Authentication=ActiveDirectoryServicePrincipal'
# ---> 10 connection = pyodbc.connect(connection_string)
#      11 cursor = connection.cursor()
#      13 # Example query
#
# ...

# %%
import pyodbc
import struct
from azure.identity import ClientSecretCredential

# Your Azure AD App Registration details
TENANT_ID = "3cb6c25b-c647-4fc3-acf1-29c27df49e62"
CLIENT_ID = "da28ca62-c4ae-4551-99cc-150bda55bb8a"
CLIENT_SECRET = "62l8Q~lRShfOFM4O~vQCF4y9U1lJtuwwB95JAbQ7"

# Get access token
credential = ClientSecretCredential(
    tenant_id=TENANT_ID,
    client_id=CLIENT_ID,
    client_secret=CLIENT_SECRET
)

token = credential.get_token("https://database.windows.net/.default")
token_bytes = token.token.encode("UTF-16-LE")
token_struct = struct.pack(f'<I{len(token_bytes)}s', len(token_bytes), token_bytes)

# Connection string — NO Uid/Pwd here
conn_str = (
    "Driver={ODBC Driver 18 for SQL Server};"
    "Server=tcp:cryptopp.database.windows.net,1433;"
    "Database=cryptopp;"
    "Encrypt=yes;"
    "TrustServerCertificate=no;"
    "Connection Timeout=30;"
)

# Pass token via SQL_COPT_SS_ACCESS_TOKEN (1256)
conn = pyodbc.connect(conn_str, attrs_before={1256: token_struct})
cursor = conn.cursor()
cursor.execute("SELECT @@VERSION")
print(cursor.fetchone())
# Out:
# ('Microsoft SQL Azure (RTM) - 12.0.2000.8 \n\tFeb  7 2026 14:31:25 \n\tCopyright (C) 2025 Microsoft Corporation\n',)
